# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from copy import deepcopy
from itertools import product
from ipywidgets import IntProgress
from IPython.display import display
import warnings

warnings.filterwarnings('ignore')

# %%
# download data
train = pd.read_csv('train_kaggle.csv')
test = pd.read_csv('test_kaggle.csv')
train['Date'] = pd.to_datetime(train['Date'], dayfirst = True)
test['Date'] = pd.to_datetime(test['Date'], dayfirst = True)
train.set_index(['Date'], inplace=True)
test.set_index(['Date'], inplace=True)

# %%
train['Promo'] = train['Promo'].fillna(0)
train.reset_index().set_index(['SKU_id', 'Store_id', 'Date'], inplace=True)
train['Regular_Price'] = train['Regular_Price'].ffill().bfill()
train.reset_index().set_index(['Date'], inplace=True)

# add actual price (promo price when promo occurred or regular price otherwise)

train['Actual_Price'] = train.Promo_Price.combine_first(train.Regular_Price) 
train.head()
# Out:
#             Store_id  SKU_id  Promo  Demand  Regular_Price  Promo_Price  \
# Date
# 2015-01-01         1       1    0.0      22         163.78          NaN
# 2015-01-02         1       1    0.0      41         163.78          NaN
# 2015-01-03         1       1    0.0      35         163.78          NaN
# 2015-01-04         1       1    0.0      72         163.78          NaN
# 2015-01-05         1       1    0.0      25         163.78          NaN
#
#             Actual_Price
# Date
# 2015-01-01        163.78
# 2015-01-02        163.78
# 2015-01-03        163.78
# 2015-01-04        163.78
# 2015-01-05        163.78

# %%
test['Promo'] = test['Promo'].fillna(0)
test.reset_index().set_index(['SKU_id', 'Store_id', 'Date'], inplace=True)
test['Regular_Price'] = test['Regular_Price'].ffill().bfill()
test.reset_index().set_index(['Date'], inplace=True)

# add actual price (promo price when promo occurred or regular price otherwise)

test['Actual_Price'] = test.Promo_Price.combine_first(test.Regular_Price) 
test.head()
# Out:
#             Store_id  SKU_id  Promo  Demand  Regular_Price  Promo_Price  \
# Date
# 2016-05-23         1       1    1.0     NaN         128.98        119.6
# 2016-05-24         1       1    0.0     NaN         128.98          NaN
# 2016-05-25         1       1    0.0     NaN         131.70          NaN
# 2016-05-26         1       1    0.0     NaN         131.70          NaN
# 2016-05-27         1       1    0.0     NaN         131.70          NaN
#
#             Actual_Price
# Date
# 2016-05-23        119.60
# 2016-05-24        128.98
# 2016-05-25        131.70
# 2016-05-26        131.70
# 2016-05-27        131.70

# %%
train.reset_index(inplace=True)
train["weekday"] = train.Date.dt.weekday
train["monthday"] = train.Date.dt.day
train['is_weekend'] = train.weekday.isin([5, 6]) * 1

test.reset_index(inplace=True)
test["weekday"] = test.Date.dt.weekday
test["monthday"] = test.Date.dt.day
test['is_weekend'] = test.weekday.isin([5, 6]) * 1

# %%
data = pd.concat([train, test]).set_index('Date').reset_index()
data.head()
# Out:
#         Date  Store_id  SKU_id  Promo  Demand  Regular_Price  Promo_Price  \
# 0 2015-01-01         1       1    0.0    22.0         163.78          NaN
# 1 2015-01-02         1       1    0.0    41.0         163.78          NaN
# 2 2015-01-03         1       1    0.0    35.0         163.78          NaN
# 3 2015-01-04         1       1    0.0    72.0         163.78          NaN
# 4 2015-01-05         1       1    0.0    25.0         163.78          NaN
#
#    Actual_Price  weekday  monthday  is_weekend
# 0        163.78        3         1           0
# 1        163.78        4         2           0
# 2        163.78        5         3           1
# 3        163.78        6         4           1
# 4        163.78        0         5           0

# %% [markdown]
# # DYNAMIC + STATIC

# %%
def percentile(n):
    '''Calculate n - percentile of data'''
    def percentile_(x):
        return np.nanpercentile(x, n)
    percentile_.__name__ = 'perc%s' % n
    return percentile_


def lagged_features(data,
                    target_vars = ['Demand'],
                    id_columns = ['SKU_id'],
                    lags = [7, 14, 21, 28],
                    windows = [1, 2, 3, 4],
                    preaggreagation_methods = ['mean'], # ['mean', 'count']
                    aggregation_methods = ['mean', 'median', percentile(10),  percentile(90)],
                    dynamic_filters = ['weekday'],
                    static_filters = None
                    ):
    '''Calculate lagged features '''
    ''' df - data frame
        target_vars - column names which are used to calculate lagged features
        by_store - whether calculate stats by stores or not
        id_columns - columns to groups
        lags - 
        windows - list of windows(string type), calculation is performed within time range length of window
        preaggreagation_methods - applied methods before rolling
        aggregation_methods - method of aggregation, e.g. 'mean', 'median', 'std', etc.
        filter = dict of dict: {<column_name>:{'postfix':'condition of the filter'}}
    '''
    
    out_df = deepcopy(data).set_index(id_columns + ['Date'])
    df = deepcopy(data)
    
    ## STATIC
    
    true_demand = df['Demand']

    if static_filters is None:
        static_filters = {'':{''}}
    
    ## total number of filters
    total = 0
    for x in flts:
        total += len(flts[x].items())
    
    progress = IntProgress(min=0, max=total)
    display(progress)
    
    for col_name in static_filters:
        for name, f in static_filters[col_name].items():
            condition = col_name + f
            if len(condition) > 0:
                idx = df.eval(condition)
            else:
                idx = df.index >= 0
        
            if len(df[idx].index) > 0:
                df.loc[~idx, 'Demand'] = np.nan
                for w in windows:
                    for preaggr in preaggreagation_methods:
                        for method in aggregation_methods:
                            if method == 'mean':
                                lf_df_ewm = df.set_index('Date').sort_index().groupby(id_columns + ['Date']).\
                                    agg(preaggr).ewm(span=w, min_periods=1).agg(method)
                            
                            
                            lf_df_rolling = df.set_index('Date').sort_index().groupby(id_columns + ['Date']).\
                                agg(preaggr).rolling(window=w * 7, min_periods=1).agg(method)

                            for l in lags:
                                method_name = method.__name__ if type(method) != str else method
                                
                                new_names_ewm = {x: "{0}_lag{1}d_w{2}d_key{3}_preag{4}_ag{5}_{6}_static_ewm".
                                             format(x, l * 7, w * 7, '_'.join(id_columns), preaggr, method_name, name) for x in lf_df_ewm.columns}
                                
                                new_names_rolling = {x: "{0}_lag{1}d_w{2}d_key{3}_preag{4}_ag{5}_{6}_static_rolling".
                                             format(x, l * 7, w * 7, '_'.join(id_columns), preaggr, method_name, name) for x in lf_df_rolling.columns}
                                
                                if method == 'mean':
                                    out_df = pd.merge(out_df, lf_df_ewm['Demand'].shift(l).reset_index().rename(columns = new_names_ewm),
                                                      how='left', on=id_columns + ['Date'])

                                out_df = pd.merge(out_df, lf_df_rolling['Demand'].shift(l).reset_index().rename(columns = new_names_rolling),
                                                  how='left', on=id_columns + ['Date'])
            df['Demand'] = true_demand
            progress.value += 1
    
    ## DYNAMIC 
    
    total = len(target_vars) * len(lags) * len(windows) * len(preaggreagation_methods) * len(aggregation_methods) * len(dynamic_filters)
    progress = IntProgress(min=0, max=total)
    display(progress)
    
    
    for f in dynamic_filters:
        for w in windows:
            
#             if w.isdigit():
#                 w += 'D'
            for preaggr in preaggreagation_methods:
                for method in aggregation_methods:
                    if method == 'mean':
                        lf_df_ewm = df.set_index('Date').sort_index().groupby([f] + id_columns + ['Date']).\
                        agg(preaggr)[target_vars].ewm(span=w, min_periods=1).agg(method)
                    
                    lf_df_rolling = df.set_index('Date').sort_index().groupby([f] + id_columns + ['Date']).\
                    agg(preaggr)[target_vars].rolling(window=w, min_periods=1).agg(method)
                    
                    for l in lags:

                        method_name = method.__name__ if type(method) != str else method
                        new_names_ewm = {x: "{0}_lag{1}d_w{2}d_key{3}_preag{4}_ag{5}_{6}_dynamic_ewm".
                                     format(x, l * 7, w * 7, '_'.join(id_columns), preaggr, method_name, f) for x in target_vars}
                        
                        new_names_rolling = {x: "{0}_lag{1}d_w{2}d_key{3}_preag{4}_ag{5}_{6}_dynamic_rolling".
                                     format(x, l * 7, w * 7, '_'.join(id_columns), preaggr, method_name, f) for x in target_vars}
                        
                        if method == 'mean':
                            out_df = pd.merge(out_df, lf_df_ewm[target_vars].shift(l).rename(columns=new_names_ewm),
                                              how='left', on=id_columns + ['Date'])
                        
                        out_df = pd.merge(out_df, lf_df_rolling[target_vars].shift(l).rename(columns=new_names_rolling),
                                          how='left', on=id_columns + ['Date'])
                        
                        progress.value += 1
    
    return out_df

# %%
flts = {
        'weekday' : {'md':'==0', 'tue':'==1', 'wd':'==2', 'th':'==3', 'fr':'==4', 'sa':'==5', 'su':'==6'}
       }

data_lagged_features = lagged_features(data, target_vars = ['Demand']
                    , id_columns = ['SKU_id']
                    , lags = [1, 2] ## weeks
                    , windows = [2, 3] ## weeks
                    , preaggreagation_methods = ['mean'] # ['mean', 'count']
                    , aggregation_methods = ['mean']
                    , dynamic_filters = ['weekday']
                    , static_filters=flts
                    )

data_lagged_features = data_lagged_features.reset_index()
# Out:
# IntProgress(value=0, max=7)
# IntProgress(value=0, max=4)

# %%
data_lagged_features.isna().sum().sort_values().tail(15)
# Out:
# Demand_lag14d_w21d_keySKU_id_preagmean_agmean_fr_static_rolling           2185
# Demand_lag14d_w21d_keySKU_id_preagmean_agmean_th_static_rolling           2258
# Demand_lag14d_w21d_keySKU_id_preagmean_agmean_wd_static_rolling           3346
# Demand_lag14d_w21d_keySKU_id_preagmean_agmean_tue_static_rolling          3413
# Demand_lag14d_w21d_keySKU_id_preagmean_agmean_md_static_rolling           3480
# Demand_lag14d_w14d_keySKU_id_preagmean_agmean_su_static_rolling           3547
# Demand_lag14d_w14d_keySKU_id_preagmean_agmean_weekday_dynamic_rolling     3562
# Demand_lag14d_w14d_keySKU_id_preagmean_agmean_sa_static_rolling           3614
# Demand_lag14d_w14d_keySKU_id_preagmean_agmean_fr_static_rolling           3681
# Demand_lag14d_w14d_keySKU_id_preagmean_agmean_th_static_rolling           3748
# Demand_lag14d_w14d_keySKU_id_preagmean_agmean_wd_static_rolling           4830
# Demand_lag14d_w14d_keySKU_id_preagmean_agmean_tue_static_rolling          4897
# Demand_lag14d_w14d_keySKU_id_preagmean_agmean_md_static_rolling           4964
# Demand                                                                    5970
# Promo_Price                                                              76023
# dtype: int64

# %% [markdown]
# # ROLLING

# %%
new_names = {}
for x in data_lagged_features.columns[11:17]:
    name = x.split('_')
    lag, w = name[0], name[1]
    preagr, agr = name[4], name[5]
    new_name = lag + ' | '+ w + '\n' +  preagr + ' | ' + agr
    new_names[x] = new_name


fig, ax = plt.subplots(2, 3, figsize = (20,12))
data_lagged_features[data_lagged_features.columns[11:17]].rename(columns=new_names).hist(ax=ax, bins=15)
plt.show()

# %%
new_names = {}
for x in data_lagged_features.columns[30:36]:
    name = x.split('_')
    lag, w = name[0], name[1]
    preagr, agr = name[4], name[5]
    new_name = lag + ' | '+ w + '\n' +  preagr + ' | ' + agr
    new_names[x] = new_name


fig, ax = plt.subplots(2, 3, figsize = (20,12))
data_lagged_features[data_lagged_features.columns[30:36]].rename(columns=new_names).hist(ax=ax, bins=15)

plt.show()

# %%
data_lagged_features[data_lagged_features['SKU_id'] == 1].set_index('Date')[['Demand', 'lag2_wdw2_keySKU_id_preagmean_agmean_Demand_dynamic']].plot(figsize=(16,9), title='Lag2Window2Mean')
# Out:
# <AxesSubplot:title={'center':'Lag2Window2Mean'}, xlabel='Date'>

# %%
data_lagged_features[data_lagged_features['SKU_id'] == 1].set_index('Date')[['Demand', 'lag2_wdw2_keySKU_id_preagmean_agmean_Demand_dynamic']].head(5000).tail(500).plot(figsize=(16,9), title='Lag2Window2Mean')
# Out:
# <AxesSubplot:title={'center':'Lag2Window2Mean'}, xlabel='Date'>

# %%
data_lagged_features[data_lagged_features['SKU_id'] == 1].set_index('Date')[['Demand', 'lag2_wdw2_keySKU_id_preagmean_agmedian_Demand_dynamic']].head(5000).tail(500).plot(figsize=(16,9), title='Lag2Window2Median')
# Out:
# <AxesSubplot:title={'center':'Lag2Window2Median'}, xlabel='Date'>

# %%
data_lagged_features[data_lagged_features['SKU_id'] == 1].set_index('Date')[['Demand', 'lag1_wdw1_keySKU_id_preagmean_agmean_Demand_dynamic']].plot(figsize=(16,9), title='Lag1Window1Mean')
# Out:
# <AxesSubplot:title={'center':'Lag1Window1Mean'}, xlabel='Date'>

# %%
data_lagged_features[data_lagged_features['SKU_id'] == 1].set_index('Date')[['Demand', 'lag1_wdw8_keySKU_id_preagmean_agmean_Demand_dynamic']].plot(figsize=(16,9), title='Lag1Window1Mean')
# Out:
# <AxesSubplot:title={'center':'Lag1Window1Mean'}, xlabel='Date'>

# %% [markdown]
# # EWM

# %%
data_lagged_features[data_lagged_features['SKU_id'] == 1].set_index('Date')[['Demand', 'Demand_lag7d_w21d_keySKU_id_preagmean_agmean_weekday_dynamic_ewm']].plot(figsize=(16,9), title='Lag7Window21Mean')
# Out:
# <AxesSubplot:title={'center':'Lag7Window21Mean'}, xlabel='Date'>

# %%
data_lagged_features[data_lagged_features['SKU_id'] == 1].set_index('Date')[['Demand', 'Demand_lag7d_w21d_keySKU_id_preagmean_agmean_weekday_dynamic_ewm']].head(5000).tail(500).plot(figsize=(16,9), title='Lag7Window21Mean')
# Out:
# <AxesSubplot:title={'center':'Lag7Window21Mean'}, xlabel='Date'>

# %%
data_lagged_features[data_lagged_features['SKU_id'] == 1].set_index('Date')[['Demand_lag7d_w21d_keySKU_id_preagmean_agmean_weekday_dynamic_ewm']].tail(800).plot(figsize=(16,9), title='Lag7Window21MeanLast100')
# Out:
# <AxesSubplot:title={'center':'Lag7Window21MeanLast100'}, xlabel='Date'>

# %% [markdown]
# # TO ANALYSE

# %%
df = deepcopy(data)
lf_df = df.set_index('Date').sort_index().groupby(['weekday', 'SKU_id'] + ['Date']).\
                            agg('mean').rolling(window=2, min_periods=1).agg('mean')


out_df = pd.merge(df, lf_df['Demand'].shift(2).reset_index().rename(columns = {'Demand': 'Rolled'}),
                                                  how='left', on=['SKU_id'] + ['Date'])

lf_df = df.set_index('Date').sort_index().groupby(['weekday', 'SKU_id'] + ['Date']).\
                            agg('mean').ewm(span=2, min_periods=1).agg('mean')


out_df = pd.merge(out_df, lf_df['Demand'].shift(2).reset_index().rename(columns = {'Demand': 'Rolled'}),
                                                  how='left', on=['SKU_id'] + ['Date'])

# %% [markdown]
# ## Rolling лучше

# %%
# out_df.set_index('Date', inplace=True)
out_df[(out_df['SKU_id'] == 2) & (out_df['Store_id'] == 1)]['Rolled_x'].plot(label='EWM')
out_df[(out_df['SKU_id'] == 2) & (out_df['Store_id'] == 1)]['Demand'].plot(label='Demand')
plt.legend()

# %%
out_df[(out_df['SKU_id'] == 2) & (out_df['Store_id'] == 1)]['Rolled_y'].plot(label='EWM')
out_df[(out_df['SKU_id'] == 2) & (out_df['Store_id'] == 1)]['Demand'].plot(label='Demand')
plt.legend()

# %% [markdown]
# # EWM Лучше

# %%
# out_df.set_index('Date', inplace=True)
out_df[(out_df['SKU_id'] == 1) & (out_df['Store_id'] == 1)]['Rolled_x'].plot(label='EWM')
out_df[(out_df['SKU_id'] == 1) & (out_df['Store_id'] == 1)]['Demand'].plot(label='Demand')
plt.legend()

# %%
# out_df.set_index('Date', inplace=True)
out_df[(out_df['SKU_id'] == 1) & (out_df['Store_id'] == 1)]['Rolled_y'].plot(label='EWM')
out_df[(out_df['SKU_id'] == 1) & (out_df['Store_id'] == 1)]['Demand'].plot(label='Demand')
plt.legend()

# %%
# df.set_index('Date').sort_index().groupby(['SKU_id'] + ['Date']).head(1)

# %%
lf_df = df.set_index(['weekday', 'SKU_id', 'Date']).sort_index().groupby(level=['weekday', 'SKU_id', 'Date']).agg('mean').rolling(14, min_periods=1).mean()
out_df = pd.merge(df, lf_df['Demand'].shift(2).reset_index().rename(columns = {'Demand': 'Rolled'}),
                                                  how='left', on=['SKU_id'] + ['Date'])

# lf_df['Demand'].shift(2).reset_index()

# %%
# data[(data['weekday'] == 0)].groupby(['SKU_id', 'Date']).mean().rolling(2, min_periods=1).mean()['Demand']

# %%
## count - useless
## при использовании shift с фильтрами, lag и window должны указываться в неделях если говорим про фильтр weekday

## posssible structures: {'dynamic': {'filter_name': 'col_name'},
##                        'static': {'col_name': {'filter_name' :'condition'}}
##                       }
